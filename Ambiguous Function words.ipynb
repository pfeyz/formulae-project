# %%
import pandas as pd
import numpy as np
from dataset import get_manchester
from functionword_tagger import FunctionWordTagger

# %%
unigrams, bigrams, trigrams = get_manchester("E:/project/Manchester/**/*.xml", 
                                            cached=True, 
                                            gram_sizes=[1, 2, 3])

# %%
unigrams = unigrams[unigrams.speaker.isin(['CHI', 'MOT'])]
bigrams = bigrams[bigrams.speaker.isin(['CHI', 'MOT'])]
trigrams = trigrams[trigrams.speaker.isin(['CHI', 'MOT'])]

# %%
until = bigrams.loc[bigrams['ngram'].str.startswith('until', na=False)]
count_until = until.groupby('ngram').size().to_frame().reset_index().rename(columns = {0:'count'})
count_until
# Out:
#                   ngram  count
# 0            until Anna      4
# 1            until Anne      1
# 2        until Caroline      7
# 3   until Christmas_Day      1
# 4           until Daddy      8
# 5               until I     13
# 6           until Jamie      1
# 7            until July      1
# 8            until June      1
# 9             until May      1
# 10    until Mister_Plod      1
# 11         until Monday      1
# 12          until Mummy      4
# 13       until Playdays      1
# 14         until Rachel      1
# 15    until Santa_Claus      1
# 16       until Saturday      2
# 17      until September      2
# 18         until Sunday      1
# 19      until Wednesday      1
# 20          until after      1
# 21            until all      2
# 22        until another      2
# 23           until come      1
# 24         until dinner      1
# 25            until end      1
# 26     until everything      1
# 27             until he      9
# 28            until his      1
# 29             until it     13
# 30           until late      1
# 31          until later      6
# 32             until my      1
# 33           until next     10
# 34            until now      1
# 35            until one      1
# 36        until quarter      1
# 37          until seven      1
# 38            until she     10
# 39        until someone      1
# 40         until summer      1
# 41        until teatime      2
# 42            until ten      1
# 43            until the     18
# 44           until they      2
# 45          until today      1
# 46       until tomorrow      5
# 47         until twenty      1
# 48             until we     15
# 49            until you     46
# 50           until your      5
# 51        untill Rachel      1
